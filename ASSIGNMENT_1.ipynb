# %% [markdown]
# <a href="https://colab.research.google.com/github/DakshCodes13/EEA_WINTER_PROJECT/blob/main/ASSIGNMENT_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data.csv')

# %%
df.head(5)
# Out:
#   Make       Model  Year             Engine Fuel Type Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)       335
# 1  BMW    1 Series  2011  premium unleaded (required)       300
# 2  BMW    1 Series  2011  premium unleaded (required)       300
# 3  BMW    1 Series  2011  premium unleaded (required)       230
# 4  BMW    1 Series  2011  premium unleaded (required)       230
#
#   Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0                6            MANUAL  rear wheel drive              2.0
# 1                6            MANUAL  rear wheel drive              2.0
# 2                6            MANUAL  rear wheel drive              2.0
# 3                6            MANUAL  rear wheel drive              2.0
# 4                6            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# ...

# %%
df[-5:]
# Out:
#           Make   Model  Year                Engine Fuel Type Engine HP  \
# 15388    Acura     ZDX  2012     premium unleaded (required)       300
# 15389    Acura     ZDX  2012     premium unleaded (required)       300
# 15390    Acura     ZDX  2012     premium unleaded (required)       300
# 15391    Acura     ZDX  2013  premium unleaded (recommended)       300
# 15392  Lincoln  Zephyr  2006                regular unleaded       221
#
#       Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# 15388                6         AUTOMATIC    all wheel drive              4.0
# 15389                6         AUTOMATIC    all wheel drive              4.0
# 15390                6         AUTOMATIC    all wheel drive              4.0
# 15391                6         AUTOMATIC    all wheel drive              4.0
# 15392                6         AUTOMATIC  front wheel drive              4.0
#
# ...

# %%
df.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP             object
# Engine Cylinders      object
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG          float64
# city mpg             float64
# Popularity           float64
# MSRP                 float64
# dtype: object

# %%
df = df.rename(columns={'Engine HP':'HP', 'Engine Cylinders':'Cylinders', 'Transmission Type':'Transmission','Driven_Wheels':'Drive Mode','highway MPG':'MPG-H','city mpg':'MPG-C','MSRP':'Price'})

# %%
df
# Out:
#           Make       Model  Year                Engine Fuel Type   HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)  335
# 1          BMW    1 Series  2011     premium unleaded (required)  300
# 2          BMW    1 Series  2011     premium unleaded (required)  300
# 3          BMW    1 Series  2011     premium unleaded (required)  230
# 4          BMW    1 Series  2011     premium unleaded (required)  230
# ...        ...         ...   ...                             ...  ...
# 15388    Acura         ZDX  2012     premium unleaded (required)  300
# 15389    Acura         ZDX  2012     premium unleaded (required)  300
# 15390    Acura         ZDX  2012     premium unleaded (required)  300
# 15391    Acura         ZDX  2013  premium unleaded (recommended)  300
# 15392  Lincoln      Zephyr  2006                regular unleaded  221
#
#       Cylinders Transmission         Drive Mode  Number of Doors  \
# ...

# %%
df = df.drop(['Engine Fuel Type', 'Market Category','Vehicle Style','Popularity','Number of Doors','Vehicle Size'], axis=1)

# %%
df
# Out:
#           Make       Model  Year   HP Cylinders Transmission  \
# 0          BMW  1 Series M  2011  335         6       MANUAL
# 1          BMW    1 Series  2011  300         6       MANUAL
# 2          BMW    1 Series  2011  300         6       MANUAL
# 3          BMW    1 Series  2011  230         6       MANUAL
# 4          BMW    1 Series  2011  230         6       MANUAL
# ...        ...         ...   ...  ...       ...          ...
# 15388    Acura         ZDX  2012  300         6    AUTOMATIC
# 15389    Acura         ZDX  2012  300         6    AUTOMATIC
# 15390    Acura         ZDX  2012  300         6    AUTOMATIC
# 15391    Acura         ZDX  2013  300         6    AUTOMATIC
# 15392  Lincoln      Zephyr  2006  221         6    AUTOMATIC
#
#               Drive Mode  MPG-H  MPG-C    Price
# 0       rear wheel drive   26.0   19.0  46135.0
# 1       rear wheel drive   28.0   19.0  40650.0
# 2       rear wheel drive   28.0   20.0  36350.0
# ...

# %%
df.head()
# Out:
#   Make       Model  Year   HP Cylinders Transmission        Drive Mode  MPG-H  \
# 0  BMW  1 Series M  2011  335         6       MANUAL  rear wheel drive   26.0
# 1  BMW    1 Series  2011  300         6       MANUAL  rear wheel drive   28.0
# 2  BMW    1 Series  2011  300         6       MANUAL  rear wheel drive   28.0
# 3  BMW    1 Series  2011  230         6       MANUAL  rear wheel drive   28.0
# 4  BMW    1 Series  2011  230         6       MANUAL  rear wheel drive   28.0
#
#    MPG-C    Price
# 0   19.0  46135.0
# 1   19.0  40650.0
# 2   20.0  36350.0
# 3   18.0  29450.0
# 4   18.0  34500.0

# %%
duplicate = df[df.duplicated()]

# %%
duplicate
# Out:
#           Make     Model  Year   HP Cylinders Transmission         Drive Mode  \
# 14         BMW  1 Series  2013  230         6       MANUAL   rear wheel drive
# 18        Audi       100  1992  172         6       MANUAL  front wheel drive
# 20        Audi       100  1992  172         6       MANUAL  front wheel drive
# 24        Audi       100  1993  172         6       MANUAL  front wheel drive
# 25        Audi       100  1993  172         6       MANUAL  front wheel drive
# ...        ...       ...   ...  ...       ...          ...                ...
# 15388    Acura       ZDX  2012  300         6    AUTOMATIC    all wheel drive
# 15389    Acura       ZDX  2012  300         6    AUTOMATIC    all wheel drive
# 15390    Acura       ZDX  2012  300         6    AUTOMATIC    all wheel drive
# 15391    Acura       ZDX  2013  300         6    AUTOMATIC    all wheel drive
# 15392  Lincoln    Zephyr  2006  221         6    AUTOMATIC  front wheel drive
#
#        MPG-H  MPG-C    Price
# ...

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (10926, 10)

# %%
describe = df.describe()

# %%
print(describe)
# Out:
#                Year         MPG-H         MPG-C         Price
# count  10926.000000  10925.000000  10925.000000  1.092500e+04
# mean    2010.734212     26.654737     19.770801  4.249660e+04
# std       20.441561      9.031109      9.259532  6.205353e+04
# min        4.000000     12.000000      7.000000  2.000000e+03
# 25%     2007.000000     22.000000     16.000000  2.199500e+04
# 50%     2015.000000     25.000000     18.000000  3.092000e+04
# 75%     2016.000000     30.000000     22.000000  4.330000e+04
# max     2017.000000    354.000000    137.000000  2.065902e+06

# %%
df.isnull().sum()
# Out:
# Make             0
# Model            0
# Year             0
# HP              69
# Cylinders       30
# Transmission     0
# Drive Mode       0
# MPG-H            1
# MPG-C            1
# Price            1
# dtype: int64

# %%
df.dropna(inplace=True)
# Out:
# <ipython-input-26-c64f9f573c18>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
HP = df['HP'].to_numpy()
Prices = df['Price'].to_numpy()
Year = df['Year'].to_numpy()
Transmission = df['Transmission'].to_numpy()
MPG_H = df['MPG-H'].to_numpy()
MPG_C = df['MPG-C'].to_numpy()
Drive_Mode = df['Drive Mode'].to_numpy()

# %%
plt.plot(HP,Prices)
plt.show()

# %%
plt.plot(MPG_H,MPG_C)
plt.show()

# %%
plt.plot(Transmission,MPG_H)
plt.show()
plt.plot(Transmission,MPG_H)
plt.show()

# %%
df['Drive Mode'].value_counts()
# Out:
# Drive Mode
# front wheel drive    4168
# rear wheel drive     3120
# all wheel drive      2281
# four wheel drive     1258
# Name: count, dtype: int64

# %%
# Most common drive mode is (Front wheel drive)

# %%
df['Year'].value_counts()
# Out:
# Year
# 2015    2029
# 2016    2022
# 2017    1580
# 2014     530
# 2012     350
# 2009     349
# 2007     332
# 2013     320
# 2008     316
# 2011     278
# 2010     272
# 2003     233
# 2004     230
# 2005     205
# 2002     203
# 2006     194
# 2001     168
# 1997     148
# 1998     143
# 1993     135
# 2000     114
# 1999     111
# 1994     109
# 1992     104
# 1995     103
# 1996      98
# 1991      84
# 1990      67
# Name: count, dtype: int64

# %%
df.groupby('Year')['Price'].sum()
# Out:
# Year
# 1990      136485.0
# 1991      180260.0
# 1992      221760.0
# 1993      303628.0
# 1994      262714.0
# 1995      281076.0
# 1996      261155.0
# 1997      489331.0
# 1998      436242.0
# 1999      353539.0
# 2000      365667.0
# 2001     6972112.0
# 2002     6878667.0
# 2003     9361892.0
# 2004     8378509.0
# 2005     7607265.0
# 2006     6222521.0
# 2007    11749997.0
# 2008    18169421.0
# 2009    18000189.0
# 2010    14405089.0
# 2011    16183416.0
# 2012    21697856.0
# 2013    16559812.0
# 2014    34521123.0
# 2015    96546626.0
# 2016    96833023.0
# 2017    66695089.0
# Name: Price, dtype: float64

# %%
newdf = df.select_dtypes(include='number')

# %%
newdf.head()
# Out:
#    Year  MPG-H  MPG-C    Price
# 0  2011   26.0   19.0  46135.0
# 1  2011   28.0   19.0  40650.0
# 2  2011   28.0   20.0  36350.0
# 3  2011   28.0   18.0  29450.0
# 4  2011   28.0   18.0  34500.0

# %%
corrM = newdf.corr()

# %%
corrM
# Out:
#            Year     MPG-H     MPG-C     Price
# Year   1.000000  0.284237  0.234135  0.196789
# MPG-H  0.284237  1.000000  0.841229 -0.209150
# MPG-C  0.234135  0.841229  1.000000 -0.234050
# Price  0.196789 -0.209150 -0.234050  1.000000

# %%
sns.heatmap(corrM,annot=True)
# Out:
# <Axes: >
